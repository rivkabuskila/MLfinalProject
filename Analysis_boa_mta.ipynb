# %%
# importing required libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


name1 = 'mta'
name2 = 'boa'
file_path1 = f'{name1}.csv'
file_path2 = f'{name2}.csv'

# קריאת הנתונים משני הקבצים
data1 = pd.read_csv(file_path1)
data2 = pd.read_csv(file_path2)
data1['label'] = "malware"
data2['label'] = "benign"

data = pd.concat([data1, data2], ignore_index=True)
X = data.iloc[:, 0:19].values
y = data.iloc[:, 21].values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# חישוב מטריצת הקורלציה
corr_matrix = data.iloc[:, 0:19].corr()

# יצירת ה-heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Heatmap of Features')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# חישוב מטריצת הקורלציה
corr_matrix = data.iloc[:, 0:19].corr()

# הגדרת סף לקורלציה גבוהה
threshold = 0.8

# מציאת כל הפיצ'רים שדומים (עם קורלציה מעל סף)
similar_features = []
for i in range(corr_matrix.shape[0]):
    for j in range(i+1, corr_matrix.shape[1]):
        if abs(corr_matrix.iloc[i, j]) > threshold:
            feature_pair = (corr_matrix.index[i], corr_matrix.columns[j])
            similar_features.append(feature_pair)
            print(f"Features {feature_pair[0]} and {feature_pair[1]} have a correlation of {corr_matrix.iloc[i, j]:.2f}")

# הדפסת הפיצ'רים להורדה
features_to_remove = set()
for pair in similar_features:
    features_to_remove.add(pair[1])  # ניתן לבחור להוריד את הפיצ'ר השני בכל זוג

print("\nFeatures to remove:")
for feature in features_to_remove:
    print(feature)

# הסרת הפיצ'רים הלא רלוונטיים מהנתונים
X_relevant = data.drop(columns=features_to_remove).iloc[:, 0:19].values
# Out:
# Features bidirectional_mean_ps and bidirectional_stddev_ps have a correlation of 0.86
# Features bidirectional_mean_ps and mean_packet_size_delta have a correlation of 0.85
# Features bidirectional_stddev_ps and bidirectional_max_ps have a correlation of 0.82
# Features bidirectional_stddev_ps and std_packet_size_delta have a correlation of 0.95
# Features bidirectional_stddev_ps and mean_packet_size_delta have a correlation of 0.87
# Features bidirectional_max_ps and std_packet_size_delta have a correlation of 0.84
# Features bidirectional_mean_piat_ms and src2dst_mean_piat_ms have a correlation of 0.87
# Features bidirectional_mean_piat_ms and src2dst_avg_packet_per_second have a correlation of 0.85
# Features bidirectional_max_piat_ms and src2dst_max_piat_ms have a correlation of 0.98
# Features bidirectional_max_piat_ms and dst2src_max_piat_ms have a correlation of 0.92
# Features src2dst_max_piat_ms and dst2src_max_piat_ms have a correlation of 0.91
# Features src2dst_mean_piat_ms and dst2src_mean_piat_ms have a correlation of 0.90
# Features src2dst_mean_piat_ms and src2dst_avg_packet_per_second have a correlation of 0.99
# Features src2dst_mean_piat_ms and dst2src_avg_packet_per_second have a correlation of 0.90
# Features dst2src_mean_piat_ms and src2dst_avg_packet_per_second have a correlation of 0.89
# Features dst2src_mean_piat_ms and dst2src_avg_packet_per_second have a correlation of 0.99
# Features src2dst_avg_packet_per_second and dst2src_avg_packet_per_second have a correlation of 0.91
#
# Features to remove:
# dst2src_max_piat_ms
# mean_packet_size_delta
# src2dst_max_piat_ms
# src2dst_mean_piat_ms
# dst2src_mean_piat_ms
# bidirectional_stddev_ps
# dst2src_avg_packet_per_second
# src2dst_avg_packet_per_second
# std_packet_size_delta
# bidirectional_max_ps

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# דוגמא ליצירת data
# data1 = pd.read_csv('data1.csv')
# data2 = pd.read_csv('data2.csv')
# data = pd.concat([data1, data2], ignore_index=True)

# מיזוג הנתונים
data = pd.concat([data1, data2], ignore_index=True)

# בחירת ה-X וה-y
X = data.iloc[:, 0:19]
y = data.iloc[:, 21]

# חישוב מטריצת הקורלציה
corr_matrix = X.corr()

# הגדרת סף לקורלציה גבוהה
threshold = 0.8

# מציאת כל הפיצ'רים שדומים (עם קורלציה מעל סף)
similar_features = []
for i in range(corr_matrix.shape[0]):
    for j in range(i+1, corr_matrix.shape[1]):
        if abs(corr_matrix.iloc[i, j]) > threshold:
            feature_pair = (corr_matrix.index[i], corr_matrix.columns[j])
            similar_features.append(feature_pair)

# הדפסת הפיצ'רים להורדה
features_to_remove = set()
for pair in similar_features:
    features_to_remove.add(pair[1])  # ניתן לבחור להוריד את הפיצ'ר השני בכל זוג

# הסרת הפיצ'רים הלא רלוונטיים מהנתונים
remaining_features = X.columns.difference(features_to_remove)
X_relevant = X[remaining_features]

# יצירת DataFrame חדש עם הפיצ'רים שנותרו והתיוגים
data_relevant = pd.concat([X_relevant, y], axis=1)

# שמירת הנתונים לאקסל
data_relevant.to_excel('remaining_features.xlsx', index=False)

print("The remaining features have been saved to 'remaining_features.xlsx'.")
# Out:
# The remaining features have been saved to 'remaining_features.xlsx'.
